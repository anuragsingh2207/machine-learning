# %%
import requests
from bs4 import BeautifulSoup
import time
import json
from textwrap import wrap

# %%
BASE_URL = "https://cloud.google.com"
DOCS_URL = "https://cloud.google.com/docs"

headers = {
    "User-Agent": "Mozilla/5.0 (compatible; GoogleCloudScraper/1.0)"
}

# %%
# Scrap the Google Cloud documentation
def get_doc_links(start_url):
    """Scrape documentation article links from the main docs page."""
    print(f"Fetching links from {start_url}...")
    links = set()
    res = requests.get(start_url, headers=headers)
    soup = BeautifulSoup(res.text, "html.parser")

    for a in soup.select("a[href^='/']"):
        href = a.get("href")
        if "/docs" in href and "/docs/" in href and not href.endswith("/docs"):
            full_url = BASE_URL + href.split("#")[0]
            links.add(full_url)

    return list(links)

def scrape_article(url):
    """Scrape title and main content from an article URL."""
    print(f"Scraping: {url}")
    res = requests.get(url, headers=headers)
    soup = BeautifulSoup(res.text, "html.parser")

    title = soup.find("h1").get_text(strip=True) if soup.find("h1") else "No title"
    paragraphs = soup.select("main p, main li")

    content = "\n".join(p.get_text(strip=True) for p in paragraphs if p.get_text(strip=True))
    return {
        "url": url,
        "title": title,
        "content": content
    }

def scrape_docs():
    doc_links = get_doc_links(DOCS_URL)
    docs_data = []

    for url in doc_links:
        try:
            data = scrape_article(url)
            if data["content"]:
                docs_data.append(data)
            time.sleep(1)  # Politeness delay
        except Exception as e:
            print(f"Error scraping {url}: {e}")

    with open("google_cloud_docs.json", "w", encoding="utf-8") as f:
        json.dump(docs_data, f, indent=2, ensure_ascii=False)

    print(f"Saved {len(docs_data)} articles.")

if __name__ == "__main__":
    scrape_docs()
# Out:
# Fetching links from https://cloud.google.com/docs...
# Scraping: https://cloud.google.com/resource-manager/docs/organization-policy/overview
# Scraping: https://cloud.google.com/vertex-ai/docs/training-overview
# Scraping: https://cloud.google.com/docs/authentication
# Scraping: https://cloud.google.com/distributed-cloud/hosted/docs/latest/gdch
# Scraping: https://cloud.google.com/free/docs/free-cloud-features
# Scraping: https://cloud.google.com/vertex-ai/docs/evaluation/introduction
# Scraping: https://cloud.google.com/network-connectivity/docs/router
# Scraping: https://cloud.google.com/docs/application-hosting
# Scraping: https://cloud.google.com/vertex-ai/docs/featurestore/latest/overview
# Scraping: https://cloud.google.com/sql/docs/mysql
# Scraping: https://cloud.google.com/carbon-footprint/docs/view-carbon-data
# Scraping: https://cloud.google.com/vertex-ai/docs/training/overview
# Scraping: https://cloud.google.com/vertex-ai/docs/open-source/ray-on-vertex-ai/overview
# Scraping: https://cloud.google.com/netapp/volumes/docs/discover/overview
# Scraping: https://cloud.google.com/docs/industry
# Scraping: https://cloud.google.com/network-connectivity/docs/interconnect
# Scraping: https://cloud.google.com/docs/security/overview/whitepaper
# Scraping: https://cloud.google.com/vertex-ai/generative-ai/docs/open-models/use-llama
# Scraping: https://cloud.google.com/vertex-ai/generative-ai/docs/open-models/use-hugging-face-models
# Scraping: https://cloud.google.com/docs/access-resources
# Scraping: https://cloud.google.com/java/docs/spring
# Scraping: https://cloud.google.com/docs/compute-area
# Scraping: https://cloud.google.com/vertex-ai/docs/workbench/instances
# Scraping: https://cloud.google.com/vertex-ai/generative-ai/docs/embeddings
# Scraping: https://cloud.google.com/docs/costs-usage
# Scraping: https://cloud.google.com/vertex-ai/docs/generative-ai/models/evaluate-models
# Scraping: https://cloud.google.com/vertex-ai/generative-ai/docs/learn/model-versions
# Scraping: https://cloud.google.com/vpc/docs/private-service-connect
# Scraping: https://cloud.google.com/vertex-ai/generative-ai/docs/learn/prompts/introduction-prompt-design
# Scraping: https://cloud.google.com/vertex-ai/docs/generative-ai/start/quickstarts/quickstart
# Scraping: https://cloud.google.com/docs/
# Scraping: https://cloud.google.com/kubernetes-engine/multi-cloud/docs/azure
# Scraping: https://cloud.google.com/vertex-ai/docs/model-monitoring/overview
# Scraping: https://cloud.google.com/vertex-ai/docs/model-registry/introduction
# Scraping: https://cloud.google.com/vertex-ai/docs/start/explore-models
# Scraping: https://cloud.google.com/firewall/docs/firewall-rules-logging
# Scraping: https://cloud.google.com/healthcare-api/docs/concepts/nlp
# Scraping: https://cloud.google.com/docs/quotas
# Scraping: https://cloud.google.com/kubernetes-engine/docs/integrations/ai-infra
# Scraping: https://cloud.google.com/bigquery/docs/data-governance
# Scraping: https://cloud.google.com/docs/product-list
# Scraping: https://cloud.google.com/compute/docs/gpus
# Scraping: https://cloud.google.com/docs/get-started
# Scraping: https://cloud.google.com/memorystore/docs/cluster
# Scraping: https://cloud.google.com/vertex-ai/docs/matching-engine
# Scraping: https://cloud.google.com/migrate/virtual-machines/docs/5.0
# Scraping: https://cloud.google.com/storage-transfer/docs/overview
# Scraping: https://cloud.google.com/docs/get-started/
# Scraping: https://cloud.google.com/generative-ai-app-builder/docs/enterprise-search-introduction
# Scraping: https://cloud.google.com/docs/cross-product-overviews
# Scraping: https://cloud.google.com/docs/security
# Scraping: https://cloud.google.com/compute/docs/disks/hyperdisks
# Scraping: https://cloud.google.com/bigquery/docs/analytics-hub-introduction
# Scraping: https://cloud.google.com/looker/docs/studio
# Scraping: https://cloud.google.com/vertex-ai/docs/pipelines/introduction
# Scraping: https://cloud.google.com/sql/docs/sqlserver
# Scraping: https://cloud.google.com/vertex-ai/docs/workbench/managed
# Scraping: https://cloud.google.com/docs/tech-area-overviews
# Scraping: https://cloud.google.com/code/docs/intellij
# Scraping: https://cloud.google.com/memorystore/docs/memcached
# Scraping: https://cloud.google.com/vertex-ai/generative-ai/docs/partner-models/use-claude
# Scraping: https://cloud.google.com/docs/observability
# Scraping: https://cloud.google.com/billing/docs/how-to/finops-hub
# Scraping: https://cloud.google.com/network-connectivity/docs/cdn-interconnect
# Scraping: https://cloud.google.com/code/docs/vscode
# Scraping: https://cloud.google.com/docs/ai-ml
# Scraping: https://cloud.google.com/docs/terraform
# Scraping: https://cloud.google.com/vertex-ai/docs/datasets/overview
# Scraping: https://cloud.google.com/sql/docs/postgres
# Scraping: https://cloud.google.com/kms/docs/hsm
# Scraping: https://cloud.google.com/compute/docs/images
# Scraping: https://cloud.google.com/network-connectivity/docs/network-connectivity-center
# Scraping: https://cloud.google.com/logging/docs/audit
# Scraping: https://cloud.google.com/network-connectivity/docs/vpn
# Scraping: https://cloud.google.com/docs/storage
# Scraping: https://cloud.google.com/docs/networking
# Scraping: https://cloud.google.com/stackdriver/docs/managed-prometheus
# Scraping: https://cloud.google.com/vertex-ai/generative-ai/docs/open-models/use-open-models
# Scraping: https://cloud.google.com/vertex-ai/generative-ai/docs/multimodal/configure-safety-attributes
# Scraping: https://cloud.google.com/bigquery/docs/migration-intro
# Scraping: https://cloud.google.com/memorystore/docs/redis
# Scraping: https://cloud.google.com/vpc/docs/flow-logs
# Scraping: https://cloud.google.com/bigquery/docs/dts-introduction
# Scraping: https://cloud.google.com/compute/docs/disks/persistent-disks
# Scraping: https://cloud.google.com/docs/gitlab
# Scraping: https://cloud.google.com/vertex-ai/generative-ai/docs/multimodal/send-chat-prompts-gemini
# Scraping: https://cloud.google.com/docs/samples
# Scraping: https://cloud.google.com/vertex-ai/docs/experiments/intro-vertex-ai-experiments
# Scraping: https://cloud.google.com/docs/devtools
# Scraping: https://cloud.google.com/docs/iac
# Scraping: https://cloud.google.com/vertex-ai/generative-ai/docs/grounding/overview
# Scraping: https://cloud.google.com/docs/buildpacks
# Scraping: https://cloud.google.com/docs/generative-ai
# Scraping: https://cloud.google.com/gemini/docs/bigquery/overview
# Scraping: https://cloud.google.com/vertex-ai/docs/predictions/overview
# Scraping: https://cloud.google.com/vertex-ai/docs/experiments/tensorboard-introduction
# Scraping: https://cloud.google.com/docs/application-development
# Scraping: https://cloud.google.com/gemini/docs/looker/overview
# Scraping: https://cloud.google.com/spanner/docs/graph
# Scraping: https://cloud.google.com/vertex-ai/docs/training/neural-architecture-search/overview
# Scraping: https://cloud.google.com/vertex-ai/docs/workbench/user-managed
# Scraping: https://cloud.google.com/docs/dhm-cloud
# Scraping: https://cloud.google.com/docs/migration
# Scraping: https://cloud.google.com/kubernetes-engine/docs/add-on/backup-for-gke
# Scraping: https://cloud.google.com/compute/docs/disks/local-ssd
# Scraping: https://cloud.google.com/vertex-ai/generative-ai/docs/open-models/use-hex-llm
# Scraping: https://cloud.google.com/vertex-ai/generative-ai/docs/learn/models
# Scraping: https://cloud.google.com/vertex-ai/generative-ai/docs/image/overview
# Scraping: https://cloud.google.com/vertex-ai/generative-ai/docs/multimodal/function-calling
# Scraping: https://cloud.google.com/vertex-ai/docs/explainable-ai/overview
# Scraping: https://cloud.google.com/document-warehouse/docs/overview
# Scraping: https://cloud.google.com/apigee/docs/hybrid/latest/what-is-hybrid
# Scraping: https://cloud.google.com/kubernetes-engine/multi-cloud/docs/attached
# Scraping: https://cloud.google.com/vertex-ai/generative-ai/docs/models/tune-models
# Scraping: https://cloud.google.com/kms/docs/ekm
# Scraping: https://cloud.google.com/docs/cuds
# Scraping: https://cloud.google.com/docs/databases
# Scraping: https://cloud.google.com/kubernetes-engine/multi-cloud/docs/aws
# Scraping: https://cloud.google.com/vertex-ai/generative-ai/docs/partner-models/use-partner-models
# Scraping: https://cloud.google.com/document-ai/docs/processors-list
# Scraping: https://cloud.google.com/vpc/docs/packet-mirroring
# Scraping: https://cloud.google.com/vertex-ai/generative-ai/docs/open-models/use-gemma
# Scraping: https://cloud.google.com/bigquery/docs/bqml-introduction
# Scraping: https://cloud.google.com/vertex-ai/docs/tabular-data/overview
# Scraping: https://cloud.google.com/docs/data
# Scraping: https://cloud.google.com/transfer-appliance/docs/4.0/overview
# Scraping: https://cloud.google.com/code/docs/shell
# Scraping: https://cloud.google.com/bigquery/docs/query-overview
# Saved 128 articles.

# %%
# Chunk the scraped documents
# Split large documents into smaller, meaningful chunks (100–300 words each) for better retrieval.

with open("google_cloud_docs.json", "r") as f:
    docs = json.load(f)
chunked_docs = []
CHUNK_SIZE = 300  # words

for doc in docs:
    words = doc["content"].split()
    chunks = wrap(" ".join(words), CHUNK_SIZE * 6)  # ~6 chars per word
    for i, chunk in enumerate(chunks):
        chunked_docs.append({
            "source_url": doc["url"],
            "title": doc["title"],
            "chunk_id": f"{doc['url']}#chunk-{i}",
            "content": chunk
        })

# Optional: save
with open("chunked_docs.json", "w") as f:
    json.dump(chunked_docs, f, indent=2)
